# %%
import pandas as pd

searches_file_path = 'contacts.tsv'
searches_data = pd.read_csv(searches_file_path, sep='\t')

searches_data.head(), searches_data.dtypes

searches_data
# Out:
#                                   id_guest  \
# 0     000dfad9-459b-4f0b-8310-3d6ab34e4f57
# 1     00197051-c6cb-4c3a-99e9-86615b819874
# 2     0027538e-aa9e-4a02-8979-b8397e5d4cba
# 3     0027538e-aa9e-4a02-8979-b8397e5d4cba
# 4     0027538e-aa9e-4a02-8979-b8397e5d4cba
# ...                                    ...
# 7818  ffe366f0-6ab6-4e94-818a-c69c125fed3c
# 7819  ffe366f0-6ab6-4e94-818a-c69c125fed3c
# 7820  ffe366f0-6ab6-4e94-818a-c69c125fed3c
# 7821  ffe366f0-6ab6-4e94-818a-c69c125fed3c
# 7822  fffea166-9432-43a7-8b1b-09d6f30c1c07
#
#                                    id_host  \
# 0     13bb24b8-d432-43a2-9755-5ea11b43bb69
# 1     46aa3897-9c00-4d76-ac66-a307593d0675
# 2     6bbb88ca-db66-48c5-9c4b-862f7706284a
# 3     8772bc85-a9b7-4d85-a52d-41f3620c2912
# 4     ac162061-55e2-4072-ac91-2e080f9581f2
# ...                                    ...
# 7818  8be6bf94-aeb3-4a51-8ac4-db60baedfea1
# 7819  b92639c1-a5a8-48f6-8484-4fe6f62d1c6d
# 7820  d0b6d89a-4379-43f2-9560-4943df5b8f4f
# ...

# %%
def mean_agg(series):
    return series.mean()

def set_agg(series):
    result = set(series.dropna().unique())
    return ', '.join(result) if result else ''

aggregation_rules = {
    'id_host': set_agg,
    'id_listing': set_agg,
    'ts_contact_at': set_agg,
    'ts_reply_at': set_agg,
    'ts_accepted_at': set_agg,
    'ts_booking_at': set_agg,
    'ds_checkin': set_agg,
    'ds_checkout': set_agg,
    'n_guests': mean_agg,
    'n_messages': mean_agg
}

# group by id_user and apply rules
grouped_searches = searches_data.groupby('id_guest').agg(aggregation_rules)

# reset the index if needed and check output
grouped_searches.reset_index(inplace=True)
print(grouped_searches.head())
# Out:
#                                id_guest  \
# 0  000dfad9-459b-4f0b-8310-3d6ab34e4f57
# 1  00197051-c6cb-4c3a-99e9-86615b819874
# 2  0027538e-aa9e-4a02-8979-b8397e5d4cba
# 3  006b68ec-9374-4061-a954-6ae10f838b9e
# 4  006c93e2-199f-4b35-a094-4176c43034be
#
#                                              id_host  \
# 0               13bb24b8-d432-43a2-9755-5ea11b43bb69
# 1               46aa3897-9c00-4d76-ac66-a307593d0675
# 2  ac162061-55e2-4072-ac91-2e080f9581f2, 8772bc85...
# 3  16a2ccae-60a6-445a-9cc4-8f0d83e454f2, 42bae547...
# 4               ee55912a-88a0-414d-aed7-7f15ce527232
#
#                                           id_listing  \
# 0               21d2b1a2-fdc3-4b4c-a1f0-0eaf0cc02370
# 1               fb5ed09a-9848-4f2c-b2ef-34deb62164fb
# 2  0d9b5583-8053-4b67-adfe-8c29eb12efed, ec68e0af...
# 3  9d8e30e9-dcc9-4148-82f7-39f7297b48f9, f375e1c9...
# 4               71bca3ca-cbbf-4496-b35b-15dcc39552da
#
#                                        ts_contact_at  \
# ...

# %%
grouped_searches
# Out:
#                                   id_guest  \
# 0     000dfad9-459b-4f0b-8310-3d6ab34e4f57
# 1     00197051-c6cb-4c3a-99e9-86615b819874
# 2     0027538e-aa9e-4a02-8979-b8397e5d4cba
# 3     006b68ec-9374-4061-a954-6ae10f838b9e
# 4     006c93e2-199f-4b35-a094-4176c43034be
# ...                                    ...
# 3278  ffc234be-ca13-4bcb-a472-1c136b800891
# 3279  ffdf7f20-8d0f-4801-8f73-3b00a1bba4c3
# 3280  ffe1316f-8628-48ff-9cec-7ae59038a231
# 3281  ffe366f0-6ab6-4e94-818a-c69c125fed3c
# 3282  fffea166-9432-43a7-8b1b-09d6f30c1c07
#
#                                                 id_host  \
# 0                  13bb24b8-d432-43a2-9755-5ea11b43bb69
# 1                  46aa3897-9c00-4d76-ac66-a307593d0675
# 2     ac162061-55e2-4072-ac91-2e080f9581f2, 8772bc85...
# 3     16a2ccae-60a6-445a-9cc4-8f0d83e454f2, 42bae547...
# 4                  ee55912a-88a0-414d-aed7-7f15ce527232
# ...                                                 ...
# ...

# %%
grouped_searches.to_csv('contacts_preprocessed.csv')
