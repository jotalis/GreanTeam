# %%
import numpy as np
import matplotlib.pyplot as plt
import pandas as pd
import seaborn as sns
# Out:
# C:\Users\lihuu\AppData\Local\Temp\ipykernel_27080\130313570.py:3: DeprecationWarning:
# Pyarrow will become a required dependency of pandas in the next major release of pandas (pandas 3.0),
# (to allow more performant data types, such as the Arrow string type, and better interoperability with other libraries)
# but was not found to be installed on your system.
# If this would cause problems for you,
# please provide us feedback at https://github.com/pandas-dev/pandas/issues/54466
#
#   import pandas as pd

# %%
searches = pd.read_csv("searches.tsv", sep="\t")
searches
# Out:
#                ds                               id_user  ds_checkin  \
# 0      2014-10-01  0000af0a-6f26-4233-9832-27efbfb36148  2014-10-09
# 1      2014-10-01  0000af0a-6f26-4233-9832-27efbfb36148  2014-10-09
# 2      2014-10-01  000cd9d3-e05b-4016-9e09-34a6f8ba2fc5         NaN
# 3      2014-10-01  000cd9d3-e05b-4016-9e09-34a6f8ba2fc5  2014-11-08
# 4      2014-10-01  001c04f0-5a94-4ee0-bf5d-3591265256de         NaN
# ...           ...                                   ...         ...
# 35732  2014-10-14  ff3c92ed-ebea-4691-a808-cc6fb73f2f55         NaN
# 35733  2014-10-14  ff61875b-1d27-4ee4-bd4e-36671d3bfed4         NaN
# 35734  2014-10-14  ff946a14-777b-4597-91b2-3277921214cd  2014-11-03
# 35735  2014-10-14  ffc681d4-3668-4448-af38-6f73bc9fb89d         NaN
# 35736  2014-10-14  ffe0f0c3-f8e3-418e-82e5-3a29fdd183bd         NaN
#
#       ds_checkout  n_searches  n_nights  n_guests_min  n_guests_max  \
# 0      2014-10-12          16       3.0             2             2
# ...

# %%
#preliminary data analysis
avg_n_max = sns.histplot(data=searches,x="n_guests_max",bins=10)

# %%
contacts = pd.read_csv("contacts.tsv", sep="\t")
contacts
# Out:
#                                   id_guest  \
# 0     000dfad9-459b-4f0b-8310-3d6ab34e4f57
# 1     00197051-c6cb-4c3a-99e9-86615b819874
# 2     0027538e-aa9e-4a02-8979-b8397e5d4cba
# 3     0027538e-aa9e-4a02-8979-b8397e5d4cba
# 4     0027538e-aa9e-4a02-8979-b8397e5d4cba
# ...                                    ...
# 7818  ffe366f0-6ab6-4e94-818a-c69c125fed3c
# 7819  ffe366f0-6ab6-4e94-818a-c69c125fed3c
# 7820  ffe366f0-6ab6-4e94-818a-c69c125fed3c
# 7821  ffe366f0-6ab6-4e94-818a-c69c125fed3c
# 7822  fffea166-9432-43a7-8b1b-09d6f30c1c07
#
#                                    id_host  \
# 0     13bb24b8-d432-43a2-9755-5ea11b43bb69
# 1     46aa3897-9c00-4d76-ac66-a307593d0675
# 2     6bbb88ca-db66-48c5-9c4b-862f7706284a
# 3     8772bc85-a9b7-4d85-a52d-41f3620c2912
# 4     ac162061-55e2-4072-ac91-2e080f9581f2
# ...                                    ...
# 7818  8be6bf94-aeb3-4a51-8ac4-db60baedfea1
# 7819  b92639c1-a5a8-48f6-8484-4fe6f62d1c6d
# 7820  d0b6d89a-4379-43f2-9560-4943df5b8f4f
# ...

# %%
preprocessed_data = pd.read_csv("final_preprocessed2.csv")
preprocessed_data.columns
# Out:
# Index(['Unnamed: 0', 'id_guest', 'id_host', 'id_listing', 'ts_contact_at',
#        'ts_reply_at', 'ts_accepted_at', 'ts_booking_at', 'ds_checkin',
#        'ds_checkout', 'n_guests', 'n_messages', 'applications', 'acceptances',
#        'ds', 'n_searches', 'n_nights', 'n_guests_min', 'n_guests_max',
#        'origin_country', 'filter_price_min', 'filter_price_max',
#        'filter_room_types', 'filter_neighborhoods', 'inquiries'],
#       dtype='object')

# %%
numerical_data = preprocessed_data.select_dtypes(include=['number'])
correlation_matrix = numerical_data.corr()
plt.figure(figsize=(10, 8))
sns.heatmap(correlation_matrix, annot=True, fmt=".2f", cmap='coolwarm', cbar=True)
plt.title('Correlation Matrix Using Seaborn')
plt.show()

# %%
sns.displot(data=preprocessed_data, x="acceptances", hue="origin_country", kind="kde",  )
# Out:
# C:\Users\lihuu\AppData\Local\Temp\ipykernel_27080\1624824633.py:1: UserWarning: Dataset has 0 variance; skipping density estimate. Pass `warn_singular=False` to disable this warning.
#   sns.displot(data=preprocessed_data, x="acceptances", hue="origin_country", kind="kde",  )

# %%
sns.histplot(data=preprocessed_data, x="acceptances")
# Out:
# <Axes: xlabel='acceptances', ylabel='Count'>

# %%
night_accept = sns.scatterplot(data=preprocessed_data, x="n_nights",y="acceptances")
night_accept.set_xlim(0,140)
# Out:
# (0.0, 140.0)

# %%
#n_nights, messages, inquiries --> acceptances
avg_n_nights = sns.histplot(data=preprocessed_data, x="n_nights",binwidth=3)

# %%
message_accept = sns.scatterplot(data=preprocessed_data, x="n_messages",y="acceptances")

# %%
mess_accept = sns.histplot(data=preprocessed_data, x="n_messages")
mess_accept.set_xlim(0,110)
# Out:
# (0.0, 110.0)

# %%
countries = sns.catplot(data=preprocessed_data, y="origin_country", x="acceptances", kind="box")

# %%
sns.scatterplot(data=preprocessed_data, x="n_searches", y="acceptances")
# Out:
# <Axes: xlabel='n_searches', ylabel='acceptances'>

# %%
message_accept = sns.scatterplot(data=preprocessed_data, x="n_messages", y="acceptances",hue="origin_country")
message_accept.set_xlim(0,60)
# Out:
# (0.0, 60.0)

# %%
no_outliers = pd.read_csv("no_outlier.csv")

# %%
sns.set_style("whitegrid")
hist = sns.displot(data=no_outliers, x="n_nights",binwidth= 1,aspect=2,hue="acceptances", palette="Blues_r" )
plt.title("Number of Nights Booked to Acceptances")
plt.xlim(0,35)
plt.xlabel("Number of Nights Booked")
# Out:
# Text(0.5, 9.444444444444438, 'Number of Nights Booked')

# %%
hist = sns.displot(data=no_outliers, x="n_messages",binwidth= 1,aspect=2,hue="acceptances", palette="Blues_r" )
plt.title("Number of Messages to Acceptances")
plt.xlim(0,40)
plt.xlabel("Number of Messages")
# Out:
# Text(0.5, 9.444444444444438, 'Number of Messages')

# %%
plt.figure(figsize=(20, 5))
boxplot = sns.barplot(data= no_outliers, x= "origin_country", y="n_messages", hue = "acceptances", palette="Blues_r", width=5)
plt.title("Origin Country to Number of Messages, Compares to Acceptances")
plt.xlabel("Origin Country")
plt.ylabel("Number of Messages")
# Out:
# Text(0, 0.5, 'Number of Messages')
